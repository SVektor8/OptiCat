# %%
import sys
sys.path.insert(0, "/Users/viktor/Documents/OptiCat/src")

from opticat.core import SuperMan
app = SuperMan(use_notebook_backend=True)
app.ui()
# Out:
# HBox(children=(Dropdown(description='Прибор', options=('ArbitraryWaveformGenerator', 'Laser', 'IntensityModula…
# VBox(children=(Textarea(value="awg = ArbitraryWaveformGenerator(mode='seq', sampling_rate=50000000000000.0, pe…
# Output()
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …
